# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import seaborn as sns
import joblib

# %%
df=joblib.load('dfo.joblib')
df
# Out:
#             mjd         year  idn   lat    lon   rho   area  carea   carl  nss
# 0      35091.28  1954.954191   21  34.0   82.0  0.58  146.0  104.0   56.0    8
# 1      35094.25  1954.962328   22  24.5  337.5  0.94    8.0   11.0   11.0    1
# 2      35100.26  1954.978794   23  35.0  336.5  0.61   30.0   19.0   19.0    1
# 3      35105.20  1954.992328   24 -24.0  251.5  0.39   36.0   20.0   20.0    1
# 4      35111.33  1955.009123    1  20.5  128.0  0.86   58.0   57.0   28.0    5
# ...         ...          ...  ...   ...    ...   ...    ...    ...    ...  ...
# 19562  55557.28  2010.987068  124  12.0  320.0  0.26   82.0   43.0   16.0    9
# 19563  55559.39  2010.992849  125 -25.7  233.5  0.86   20.0   20.0   15.0    2
# 19564  55561.31  2010.998109  125 -27.3  234.4  0.63    8.0    5.0    3.0    2
# 19565  55561.31  2010.998109  126  34.7  266.9  0.61  102.0   64.0   38.0    5
# 19566  55561.31  2010.998109  127  31.4  190.8  0.97  116.0  246.0  246.0    1
#
# ...

# %%
fig, axes = plt.subplots(2,3, figsize=(10,6))
axes[0,0].scatter(df.lon, df.lat, alpha = 0.1,s=.2)
axes[0,1].scatter(df.year,df.lon, alpha =0.1,s=.2)
axes[0,2].scatter(df.year,df.lat, alpha =0.1,s=.2)
axes[1,0].hist(df.lat,30, alpha =0.1)
axes[1,1].hist(df.carea, 20, log=True, alpha =0.1)
axes[1,2].scatter(df.year,df.carea, alpha =0.1,s=.2)
axes[0,0].set_title("lon-lat")
axes[0,1].set_title("year-lon")
axes[0,2].set_title("year-lat")
axes[1,0].set_title("lat")
axes[1,1].set_title("carea")
axes[1,2].set_title("year-carea")
# Out:
# Text(0.5, 1.0, 'year-carea')

# %%
df['lat'].plot.density()

# %%
fig2 = plt.figure(figsize=(8,10))
p= sns.scatterplot(data=df[df.year<1962], x="lon" , y="year" , size="carea" , sizes=(20,200), alpha=.3, hue='year' )
sns.kdeplot(data=df[df.year<1962], x="lon" , y="year" , bw_adjust=.2 , alpha=.5 , tresh =.5, color='blue')
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:1213: UserWarning: The following kwargs were not used by contour: 'tresh'
#   **contour_kws,
